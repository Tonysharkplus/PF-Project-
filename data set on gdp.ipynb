# %% [markdown]
# # import pandas

# %%
import pandas as pd
S

# %%
import matplotlib.pyplot as plt

# %%
import scipy.stats as stats

# %% [markdown]
# # First load the data.

# %%
pd.read_csv("Europe_GDP.csv")
# Out:
#     Year       Austria       Belgium       Denmark       Finland  \
# 0   2004  3.014580e+11  3.692150e+11  2.513730e+11  1.974790e+11
# 1   2005  3.160920e+11  3.857150e+11  2.644670e+11  2.048850e+11
# 2   2006  3.362800e+11  4.082600e+11  2.828850e+11  2.170890e+11
# 3   2007  3.891860e+11  4.709220e+11  3.194230e+11  2.563780e+11
# 4   2008  4.320520e+11  5.173280e+11  3.533610e+11  2.857160e+11
# 5   2009  4.017590e+11  4.832540e+11  3.212410e+11  2.534980e+11
# 6   2010  3.922750e+11  4.814210e+11  3.219950e+11  2.494240e+11
# 7   2011  4.316850e+11  5.233300e+11  3.440030e+11  2.756040e+11
# 8   2012  4.094020e+11  4.961530e+11  3.271490e+11  2.582900e+11
# 9   2013  4.301910e+11  5.217910e+11  3.435840e+11  2.713620e+11
# 10  2014  4.425850e+11  5.353900e+11  3.529940e+11  2.748630e+11
# 11  2015  3.819710e+11  4.623360e+11  3.026730e+11  2.345340e+11
# 12  2016  3.958370e+11  4.760630e+11  3.131160e+11  2.407710e+11
# ...

# %% [markdown]
# ## inspect the data

# %%
df = pd.read_csv("Europe_GDP.csv")

# %%
df
# Out:
#     Year       Austria       Belgium       Denmark       Finland  \
# 0   2004  3.014580e+11  3.692150e+11  2.513730e+11  1.974790e+11
# 1   2005  3.160920e+11  3.857150e+11  2.644670e+11  2.048850e+11
# 2   2006  3.362800e+11  4.082600e+11  2.828850e+11  2.170890e+11
# 3   2007  3.891860e+11  4.709220e+11  3.194230e+11  2.563780e+11
# 4   2008  4.320520e+11  5.173280e+11  3.533610e+11  2.857160e+11
# 5   2009  4.017590e+11  4.832540e+11  3.212410e+11  2.534980e+11
# 6   2010  3.922750e+11  4.814210e+11  3.219950e+11  2.494240e+11
# 7   2011  4.316850e+11  5.233300e+11  3.440030e+11  2.756040e+11
# 8   2012  4.094020e+11  4.961530e+11  3.271490e+11  2.582900e+11
# 9   2013  4.301910e+11  5.217910e+11  3.435840e+11  2.713620e+11
# 10  2014  4.425850e+11  5.353900e+11  3.529940e+11  2.748630e+11
# 11  2015  3.819710e+11  4.623360e+11  3.026730e+11  2.345340e+11
# 12  2016  3.958370e+11  4.760630e+11  3.131160e+11  2.407710e+11
# ...

# %%
df.sample(4)
# Out:
#     Year       Austria       Belgium       Denmark       Finland  \
# 6   2010  3.922750e+11  4.814210e+11  3.219950e+11  2.494240e+11
# 10  2014  4.425850e+11  5.353900e+11  3.529940e+11  2.748630e+11
# 19  2023  5.160340e+11  6.322170e+11  4.041990e+11  3.001870e+11
# 8   2012  4.094020e+11  4.961530e+11  3.271490e+11  2.582900e+11
#
#           France       Germany        Greece      Iceland       Ireland  \
# 6   2.645190e+12  3.399670e+12  2.971250e+11  13751161918  2.219140e+11
# 10  2.855960e+12  3.889090e+12  2.354580e+11  17867662178  2.596820e+11
# 19  3.030900e+12  4.456080e+12  2.382060e+11  31020032583  5.456290e+11
# 8   2.683670e+12  3.527140e+12  2.420290e+11  14751508134  2.251190e+11
#
#            Italy   Luxembourg   Netherlands        Norway      Portugal  \
# 6   2.136100e+12  56213985987  8.473810e+11  4.310520e+11  2.381130e+11
# 10  2.162010e+12  68804811898  8.921680e+11  5.017360e+11  2.299020e+11
# ...

# %%
df.head(4)
# Out:
#    Year       Austria       Belgium       Denmark       Finland        France  \
# 0  2004  3.014580e+11  3.692150e+11  2.513730e+11  1.974790e+11  2.119630e+12
# 1  2005  3.160920e+11  3.857150e+11  2.644670e+11  2.048850e+11  2.196950e+12
# 2  2006  3.362800e+11  4.082600e+11  2.828850e+11  2.170890e+11  2.320540e+12
# 3  2007  3.891860e+11  4.709220e+11  3.194230e+11  2.563780e+11  2.660590e+12
#
#         Germany        Greece      Iceland       Ireland         Italy  \
# 0  2.814350e+12  2.409640e+11  13825302536  1.943720e+11  1.806540e+12
# 1  2.846860e+12  2.478750e+11  16852963067  2.118770e+11  1.858220e+12
# 2  2.994700e+12  2.735470e+11  17465318552  2.321810e+11  1.949550e+12
# 3  3.425580e+12  3.189030e+11  21652505597  2.700790e+11  2.213100e+12
#
#     Luxembourg   Netherlands        Norway      Portugal         Spain  \
# 0  35064843793  6.583800e+11  2.652690e+11  1.893820e+11  1.069060e+12
# 1  37672280120  6.853480e+11  3.099790e+11  1.972540e+11  1.153720e+12
# ...

# %%
df.tail(4)
# Out:
#     Year       Austria       Belgium       Denmark       Finland  \
# 16  2020  4.350490e+11  5.260220e+11  3.547630e+11  2.718860e+11
# 17  2021  4.792950e+11  6.009040e+11  4.056880e+11  2.964700e+11
# 18  2022  4.709420e+11  5.836140e+11  4.001670e+11  2.818870e+11
# 19  2023  5.160340e+11  6.322170e+11  4.041990e+11  3.001870e+11
#
#           France       Germany        Greece      Iceland       Ireland  \
# 16  2.647420e+12  3.887730e+12  1.884800e+11  21629953194  4.286090e+11
# 17  2.959360e+12  4.278500e+12  2.146680e+11  25797870984  5.133920e+11
# 18  2.779090e+12  4.082470e+12  2.175810e+11  28701830402  5.331400e+11
# 19  3.030900e+12  4.456080e+12  2.382060e+11  31020032583  5.456290e+11
#
#            Italy   Luxembourg   Netherlands        Norway      Portugal  \
# 16  1.897460e+12  73699366700  9.097930e+11  3.676330e+11  2.290320e+11
# 17  2.154880e+12  85584105994  1.029680e+12  5.033680e+11  2.555350e+11
# ...

# %%
df.shape
# Out:
# (20, 19)

# %%
df.size
# Out:
# 380

# %%
df.Austria
# Out:
# 0     3.014580e+11
# 1     3.160920e+11
# 2     3.362800e+11
# 3     3.891860e+11
# 4     4.320520e+11
# 5     4.017590e+11
# 6     3.922750e+11
# 7     4.316850e+11
# 8     4.094020e+11
# 9     4.301910e+11
# 10    4.425850e+11
# 11    3.819710e+11
# 12    3.958370e+11
# 13    4.172610e+11
# 14    4.549910e+11
# 15    4.445960e+11
# 16    4.350490e+11
# 17    4.792950e+11
# 18    4.709420e+11
# 19    5.160340e+11
# Name: Austria, dtype: float64

# %%
df.dtypes
# Out:
# Year                int64
# Austria           float64
# Belgium           float64
# Denmark           float64
# Finland           float64
# France            float64
# Germany           float64
# Greece            float64
# Iceland             int64
# Ireland           float64
# Italy             float64
# Luxembourg          int64
# Netherlands       float64
# Norway            float64
# Portugal          float64
# Spain             float64
# Sweden            float64
# Switzerland       float64
# United Kingdom    float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            20 non-null     int64
#  1   Austria         20 non-null     float64
#  2   Belgium         20 non-null     float64
#  3   Denmark         20 non-null     float64
#  4   Finland         20 non-null     float64
#  5   France          20 non-null     float64
#  6   Germany         20 non-null     float64
#  7   Greece          20 non-null     float64
#  8   Iceland         20 non-null     int64
#  9   Ireland         20 non-null     float64
#  10  Italy           20 non-null     float64
#  11  Luxembourg      20 non-null     int64
#  12  Netherlands     20 non-null     float64
#  13  Norway          20 non-null     float64
#  14  Portugal        20 non-null     float64
#  15  Spain           20 non-null     float64
#  16  Sweden          20 non-null     float64
# ...

# %%
df.values
# Out:
# array([[2.00400000e+03, 3.01458000e+11, 3.69215000e+11, 2.51373000e+11,
#         1.97479000e+11, 2.11963000e+12, 2.81435000e+12, 2.40964000e+11,
#         1.38253025e+10, 1.94372000e+11, 1.80654000e+12, 3.50648438e+10,
#         6.58380000e+11, 2.65269000e+11, 1.89382000e+11, 1.06906000e+12,
#         3.85118000e+11, 4.03913000e+11, 2.42153000e+12],
#        [2.00500000e+03, 3.16092000e+11, 3.85715000e+11, 2.64467000e+11,
#         2.04885000e+11, 2.19695000e+12, 2.84686000e+12, 2.47875000e+11,
#         1.68529631e+10, 2.11877000e+11, 1.85822000e+12, 3.76722801e+10,
#         6.85348000e+11, 3.09979000e+11, 1.97254000e+11, 1.15372000e+12,
#         3.92218000e+11, 4.18285000e+11, 2.54318000e+12],
#        [2.00600000e+03, 3.36280000e+11, 4.08260000e+11, 2.82885000e+11,
#         2.17089000e+11, 2.32054000e+12, 2.99470000e+12, 2.73547000e+11,
#         1.74653186e+10, 2.32181000e+11, 1.94955000e+12, 4.29101463e+10,
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=20, step=1)

# %%
df.describe()
# Out:
#              Year       Austria       Belgium       Denmark       Finland  \
# count    20.00000  2.000000e+01  2.000000e+01  2.000000e+01  2.000000e+01
# mean   2013.50000  4.139470e+11  5.027932e+11  3.349271e+11  2.585097e+11
# std       5.91608  5.311913e+10  6.608428e+10  4.150251e+10  2.818200e+10
# min    2004.00000  3.014580e+11  3.692150e+11  2.513730e+11  1.974790e+11
# 25%    2008.75000  3.915028e+11  4.747778e+11  3.178462e+11  2.472608e+11
# 50%    2013.50000  4.237260e+11  5.100465e+11  3.378525e+11  2.634025e+11
# 75%    2018.25000  4.430878e+11  5.355090e+11  3.537115e+11  2.756300e+11
# max    2023.00000  5.160340e+11  6.322170e+11  4.056880e+11  3.001870e+11
#
#              France       Germany        Greece       Iceland       Ireland  \
# count  2.000000e+01  2.000000e+01  2.000000e+01  2.000000e+01  2.000000e+01
# mean   2.661733e+12  3.631186e+12  2.464968e+11  1.999363e+10  3.169479e+11
# ...

# %%
df.describe(include='all')
# Out:
#              Year       Austria       Belgium       Denmark       Finland  \
# count    20.00000  2.000000e+01  2.000000e+01  2.000000e+01  2.000000e+01
# mean   2013.50000  4.139470e+11  5.027932e+11  3.349271e+11  2.585097e+11
# std       5.91608  5.311913e+10  6.608428e+10  4.150251e+10  2.818200e+10
# min    2004.00000  3.014580e+11  3.692150e+11  2.513730e+11  1.974790e+11
# 25%    2008.75000  3.915028e+11  4.747778e+11  3.178462e+11  2.472608e+11
# 50%    2013.50000  4.237260e+11  5.100465e+11  3.378525e+11  2.634025e+11
# 75%    2018.25000  4.430878e+11  5.355090e+11  3.537115e+11  2.756300e+11
# max    2023.00000  5.160340e+11  6.322170e+11  4.056880e+11  3.001870e+11
#
#              France       Germany        Greece       Iceland       Ireland  \
# count  2.000000e+01  2.000000e+01  2.000000e+01  2.000000e+01  2.000000e+01
# mean   2.661733e+12  3.631186e+12  2.464968e+11  1.999363e+10  3.169479e+11
# ...

# %%
df.columns
# Out:
# Index(['Year', 'Austria', 'Belgium', 'Denmark', 'Finland', 'France', 'Germany',
#        'Greece', 'Iceland', 'Ireland', 'Italy', 'Luxembourg', 'Netherlands',
#        'Norway', 'Portugal', 'Spain', 'Sweden', 'Switzerland',
#        'United Kingdom'],
#       dtype='object')

# %% [markdown]
# ## Handle missing values.
# ### for finding all the null values as seen in the series column

# %%
df.isnull().sum()
# Out:
# Year              0
# Austria           0
# Belgium           0
# Denmark           0
# Finland           0
# France            0
# Germany           0
# Greece            0
# Iceland           0
# Ireland           0
# Italy             0
# Luxembourg        0
# Netherlands       0
# Norway            0
# Portugal          0
# Spain             0
# Sweden            0
# Switzerland       0
# United Kingdom    0
# dtype: int64

# %%
df.fillna("None")
# Out:
#     Year       Austria       Belgium       Denmark       Finland  \
# 0   2004  3.014580e+11  3.692150e+11  2.513730e+11  1.974790e+11
# 1   2005  3.160920e+11  3.857150e+11  2.644670e+11  2.048850e+11
# 2   2006  3.362800e+11  4.082600e+11  2.828850e+11  2.170890e+11
# 3   2007  3.891860e+11  4.709220e+11  3.194230e+11  2.563780e+11
# 4   2008  4.320520e+11  5.173280e+11  3.533610e+11  2.857160e+11
# 5   2009  4.017590e+11  4.832540e+11  3.212410e+11  2.534980e+11
# 6   2010  3.922750e+11  4.814210e+11  3.219950e+11  2.494240e+11
# 7   2011  4.316850e+11  5.233300e+11  3.440030e+11  2.756040e+11
# 8   2012  4.094020e+11  4.961530e+11  3.271490e+11  2.582900e+11
# 9   2013  4.301910e+11  5.217910e+11  3.435840e+11  2.713620e+11
# 10  2014  4.425850e+11  5.353900e+11  3.529940e+11  2.748630e+11
# 11  2015  3.819710e+11  4.623360e+11  3.026730e+11  2.345340e+11
# 12  2016  3.958370e+11  4.760630e+11  3.131160e+11  2.407710e+11
# ...

# %%
df.dropna(inplace=True)
df
# Out:
#     Year       Austria       Belgium       Denmark       Finland  \
# 0   2004  3.014580e+11  3.692150e+11  2.513730e+11  1.974790e+11
# 1   2005  3.160920e+11  3.857150e+11  2.644670e+11  2.048850e+11
# 2   2006  3.362800e+11  4.082600e+11  2.828850e+11  2.170890e+11
# 3   2007  3.891860e+11  4.709220e+11  3.194230e+11  2.563780e+11
# 4   2008  4.320520e+11  5.173280e+11  3.533610e+11  2.857160e+11
# 5   2009  4.017590e+11  4.832540e+11  3.212410e+11  2.534980e+11
# 6   2010  3.922750e+11  4.814210e+11  3.219950e+11  2.494240e+11
# 7   2011  4.316850e+11  5.233300e+11  3.440030e+11  2.756040e+11
# 8   2012  4.094020e+11  4.961530e+11  3.271490e+11  2.582900e+11
# 9   2013  4.301910e+11  5.217910e+11  3.435840e+11  2.713620e+11
# 10  2014  4.425850e+11  5.353900e+11  3.529940e+11  2.748630e+11
# 11  2015  3.819710e+11  4.623360e+11  3.026730e+11  2.345340e+11
# 12  2016  3.958370e+11  4.760630e+11  3.131160e+11  2.407710e+11
# ...

# %% [markdown]
# ### If you want to drop a specific column from data frame we use:

# %%
df=df.drop(columns=["Austria"])
df
# Out:
#     Year       Belgium       Denmark       Finland        France  \
# 0   2004  3.692150e+11  2.513730e+11  1.974790e+11  2.119630e+12
# 1   2005  3.857150e+11  2.644670e+11  2.048850e+11  2.196950e+12
# 2   2006  4.082600e+11  2.828850e+11  2.170890e+11  2.320540e+12
# 3   2007  4.709220e+11  3.194230e+11  2.563780e+11  2.660590e+12
# 4   2008  5.173280e+11  3.533610e+11  2.857160e+11  2.930300e+12
# 5   2009  4.832540e+11  3.212410e+11  2.534980e+11  2.700890e+12
# 6   2010  4.814210e+11  3.219950e+11  2.494240e+11  2.645190e+12
# 7   2011  5.233300e+11  3.440030e+11  2.756040e+11  2.865160e+12
# 8   2012  4.961530e+11  3.271490e+11  2.582900e+11  2.683670e+12
# 9   2013  5.217910e+11  3.435840e+11  2.713620e+11  2.811880e+12
# 10  2014  5.353900e+11  3.529940e+11  2.748630e+11  2.855960e+12
# 11  2015  4.623360e+11  3.026730e+11  2.345340e+11  2.439190e+12
# 12  2016  4.760630e+11  3.131160e+11  2.407710e+11  2.472960e+12
# ...

# %%
del df["Belgium"]
df
# Out:
#     Year       Denmark       Finland        France       Germany  \
# 0   2004  2.513730e+11  1.974790e+11  2.119630e+12  2.814350e+12
# 1   2005  2.644670e+11  2.048850e+11  2.196950e+12  2.846860e+12
# 2   2006  2.828850e+11  2.170890e+11  2.320540e+12  2.994700e+12
# 3   2007  3.194230e+11  2.563780e+11  2.660590e+12  3.425580e+12
# 4   2008  3.533610e+11  2.857160e+11  2.930300e+12  3.745260e+12
# 5   2009  3.212410e+11  2.534980e+11  2.700890e+12  3.411260e+12
# 6   2010  3.219950e+11  2.494240e+11  2.645190e+12  3.399670e+12
# 7   2011  3.440030e+11  2.756040e+11  2.865160e+12  3.749310e+12
# 8   2012  3.271490e+11  2.582900e+11  2.683670e+12  3.527140e+12
# 9   2013  3.435840e+11  2.713620e+11  2.811880e+12  3.733800e+12
# 10  2014  3.529940e+11  2.748630e+11  2.855960e+12  3.889090e+12
# 11  2015  3.026730e+11  2.345340e+11  2.439190e+12  3.357590e+12
# 12  2016  3.131160e+11  2.407710e+11  2.472960e+12  3.469850e+12
# ...

# %% [markdown]
# ## Rename the columns for better readability.

# %%
df.rename(columns={"Denmark":"Dennny"},inplace=True)
df
# Out:
#     Year        Dennny       Finland        France       Germany  \
# 0   2004  2.513730e+11  1.974790e+11  2.119630e+12  2.814350e+12
# 1   2005  2.644670e+11  2.048850e+11  2.196950e+12  2.846860e+12
# 2   2006  2.828850e+11  2.170890e+11  2.320540e+12  2.994700e+12
# 3   2007  3.194230e+11  2.563780e+11  2.660590e+12  3.425580e+12
# 4   2008  3.533610e+11  2.857160e+11  2.930300e+12  3.745260e+12
# 5   2009  3.212410e+11  2.534980e+11  2.700890e+12  3.411260e+12
# 6   2010  3.219950e+11  2.494240e+11  2.645190e+12  3.399670e+12
# 7   2011  3.440030e+11  2.756040e+11  2.865160e+12  3.749310e+12
# 8   2012  3.271490e+11  2.582900e+11  2.683670e+12  3.527140e+12
# 9   2013  3.435840e+11  2.713620e+11  2.811880e+12  3.733800e+12
# 10  2014  3.529940e+11  2.748630e+11  2.855960e+12  3.889090e+12
# 11  2015  3.026730e+11  2.345340e+11  2.439190e+12  3.357590e+12
# 12  2016  3.131160e+11  2.407710e+11  2.472960e+12  3.469850e+12
# ...

# %% [markdown]
# ## Finding the duplicate values.

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates()
# Out:
#     Year        Dennny       Finland        France       Germany  \
# 0   2004  2.513730e+11  1.974790e+11  2.119630e+12  2.814350e+12
# 1   2005  2.644670e+11  2.048850e+11  2.196950e+12  2.846860e+12
# 2   2006  2.828850e+11  2.170890e+11  2.320540e+12  2.994700e+12
# 3   2007  3.194230e+11  2.563780e+11  2.660590e+12  3.425580e+12
# 4   2008  3.533610e+11  2.857160e+11  2.930300e+12  3.745260e+12
# 5   2009  3.212410e+11  2.534980e+11  2.700890e+12  3.411260e+12
# 6   2010  3.219950e+11  2.494240e+11  2.645190e+12  3.399670e+12
# 7   2011  3.440030e+11  2.756040e+11  2.865160e+12  3.749310e+12
# 8   2012  3.271490e+11  2.582900e+11  2.683670e+12  3.527140e+12
# 9   2013  3.435840e+11  2.713620e+11  2.811880e+12  3.733800e+12
# 10  2014  3.529940e+11  2.748630e+11  2.855960e+12  3.889090e+12
# 11  2015  3.026730e+11  2.345340e+11  2.439190e+12  3.357590e+12
# 12  2016  3.131160e+11  2.407710e+11  2.472960e+12  3.469850e+12
# ...

# %%
df["means"]=df["Year"].mean()
df
# Out:
#     Year        Dennny       Finland        France       Germany  \
# 0   2004  2.513730e+11  1.974790e+11  2.119630e+12  2.814350e+12
# 1   2005  2.644670e+11  2.048850e+11  2.196950e+12  2.846860e+12
# 2   2006  2.828850e+11  2.170890e+11  2.320540e+12  2.994700e+12
# 3   2007  3.194230e+11  2.563780e+11  2.660590e+12  3.425580e+12
# 4   2008  3.533610e+11  2.857160e+11  2.930300e+12  3.745260e+12
# 5   2009  3.212410e+11  2.534980e+11  2.700890e+12  3.411260e+12
# 6   2010  3.219950e+11  2.494240e+11  2.645190e+12  3.399670e+12
# 7   2011  3.440030e+11  2.756040e+11  2.865160e+12  3.749310e+12
# 8   2012  3.271490e+11  2.582900e+11  2.683670e+12  3.527140e+12
# 9   2013  3.435840e+11  2.713620e+11  2.811880e+12  3.733800e+12
# 10  2014  3.529940e+11  2.748630e+11  2.855960e+12  3.889090e+12
# 11  2015  3.026730e+11  2.345340e+11  2.439190e+12  3.357590e+12
# 12  2016  3.131160e+11  2.407710e+11  2.472960e+12  3.469850e+12
# ...

# %% [markdown]
# ### Eliminate a specific row

# %%
df.drop(19)
# Out:
#     Year        Dennny       Finland        France       Germany  \
# 0   2004  2.513730e+11  1.974790e+11  2.119630e+12  2.814350e+12
# 1   2005  2.644670e+11  2.048850e+11  2.196950e+12  2.846860e+12
# 2   2006  2.828850e+11  2.170890e+11  2.320540e+12  2.994700e+12
# 3   2007  3.194230e+11  2.563780e+11  2.660590e+12  3.425580e+12
# 4   2008  3.533610e+11  2.857160e+11  2.930300e+12  3.745260e+12
# 5   2009  3.212410e+11  2.534980e+11  2.700890e+12  3.411260e+12
# 6   2010  3.219950e+11  2.494240e+11  2.645190e+12  3.399670e+12
# 7   2011  3.440030e+11  2.756040e+11  2.865160e+12  3.749310e+12
# 8   2012  3.271490e+11  2.582900e+11  2.683670e+12  3.527140e+12
# 9   2013  3.435840e+11  2.713620e+11  2.811880e+12  3.733800e+12
# 10  2014  3.529940e+11  2.748630e+11  2.855960e+12  3.889090e+12
# 11  2015  3.026730e+11  2.345340e+11  2.439190e+12  3.357590e+12
# 12  2016  3.131160e+11  2.407710e+11  2.472960e+12  3.469850e+12
# ...

# %% [markdown]
# ### Data selection:

# %%
# TO ADD A ROW
df.loc[19]=[2000, 1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000, 11000, 12000, 13000, 14000, 15000, 16000, 17000]
df
# Out:
#     Year        Dennny       Finland        France       Germany  \
# 0   2004  2.513730e+11  1.974790e+11  2.119630e+12  2.814350e+12
# 1   2005  2.644670e+11  2.048850e+11  2.196950e+12  2.846860e+12
# 2   2006  2.828850e+11  2.170890e+11  2.320540e+12  2.994700e+12
# 3   2007  3.194230e+11  2.563780e+11  2.660590e+12  3.425580e+12
# 4   2008  3.533610e+11  2.857160e+11  2.930300e+12  3.745260e+12
# 5   2009  3.212410e+11  2.534980e+11  2.700890e+12  3.411260e+12
# 6   2010  3.219950e+11  2.494240e+11  2.645190e+12  3.399670e+12
# 7   2011  3.440030e+11  2.756040e+11  2.865160e+12  3.749310e+12
# 8   2012  3.271490e+11  2.582900e+11  2.683670e+12  3.527140e+12
# 9   2013  3.435840e+11  2.713620e+11  2.811880e+12  3.733800e+12
# 10  2014  3.529940e+11  2.748630e+11  2.855960e+12  3.889090e+12
# 11  2015  3.026730e+11  2.345340e+11  2.439190e+12  3.357590e+12
# 12  2016  3.131160e+11  2.407710e+11  2.472960e+12  3.469850e+12
# ...

# %%
df.loc[18]
# Out:
# Year              2.022000e+03
# Dennny            4.001670e+11
# Finland           2.818870e+11
# France            2.779090e+12
# Germany           4.082470e+12
# Greece            2.175810e+11
# Iceland           2.870183e+10
# Ireland           5.331400e+11
# Italy             2.066970e+12
# Luxembourg        8.164181e+10
# Netherlands       1.009400e+12
# Norway            5.937270e+11
# Portugal          2.551970e+11
# Spain             1.417800e+12
# Sweden            5.904100e+11
# Switzerland       8.184270e+11
# United Kingdom    3.088840e+12
# means             2.013500e+03
# Name: 18, dtype: float64

# %%
# to find info of a row in specific columns
df.loc[3,["Finland","Dennny"]]
# Out:
# Finland    2.563780e+11
# Dennny     3.194230e+11
# Name: 3, dtype: float64

# %%
# Data selection using iloc(it is used to select data by index position) its for row :
df.iloc[:3]
# Out:
#    Year        Dennny       Finland        France       Germany        Greece  \
# 0  2004  2.513730e+11  1.974790e+11  2.119630e+12  2.814350e+12  2.409640e+11
# 1  2005  2.644670e+11  2.048850e+11  2.196950e+12  2.846860e+12  2.478750e+11
# 2  2006  2.828850e+11  2.170890e+11  2.320540e+12  2.994700e+12  2.735470e+11
#
#        Iceland       Ireland         Italy   Luxembourg   Netherlands  \
# 0  13825302536  1.943720e+11  1.806540e+12  35064843793  6.583800e+11
# 1  16852963067  2.118770e+11  1.858220e+12  37672280120  6.853480e+11
# 2  17465318552  2.321810e+11  1.949550e+12  42910146296  7.339550e+11
#
#          Norway      Portugal         Spain        Sweden   Switzerland  \
# 0  2.652690e+11  1.893820e+11  1.069060e+12  3.851180e+11  4.039130e+11
# 1  3.099790e+11  1.972540e+11  1.153720e+12  3.922180e+11  4.182850e+11
# 2  3.469150e+11  2.087560e+11  1.260400e+12  4.230930e+11  4.416350e+11
#
#    United Kingdom   means
# 0    2.421530e+12  2013.5
# ...

# %%
# for columns:
df.iloc[:3,:4]
# Out:
#    Year        Dennny       Finland        France
# 0  2004  2.513730e+11  1.974790e+11  2.119630e+12
# 1  2005  2.644670e+11  2.048850e+11  2.196950e+12
# 2  2006  2.828850e+11  2.170890e+11  2.320540e+12

# %% [markdown]
# ### To get statistical insights from the data we do:

# %%
# Mean of Year
df["Year"].mean()
# Out:
# np.float64(2012.35)

# %%
# Median of Year
df["Year"].median()
# Out:
# np.float64(2012.5)

# %%
# Maximum of Year
df["Year"].max()
# Out:
# np.int64(2022)

# %%
# Minimum of Year
df["Year"].min()
# Out:
# np.int64(2000)

# %%
# mode of Year
df["Year"].mode()
# Out:
# 0     2000
# 1     2004
# 2     2005
# 3     2006
# 4     2007
# 5     2008
# 6     2009
# 7     2010
# 8     2011
# 9     2012
# 10    2013
# 11    2014
# 12    2015
# 13    2016
# 14    2017
# 15    2018
# 16    2019
# 17    2020
# 18    2021
# 19    2022
# Name: Year, dtype: int64

# %%
df["Year"]=df["Year"].astype("float")
df.dtypes
# Out:
# Year              float64
# Dennny            float64
# Finland           float64
# France            float64
# Germany           float64
# Greece            float64
# Iceland             int64
# Ireland           float64
# Italy             float64
# Luxembourg          int64
# Netherlands       float64
# Norway            float64
# Portugal          float64
# Spain             float64
# Sweden            float64
# Switzerland       float64
# United Kingdom    float64
# means             float64
# dtype: object

# %%
df.groupby("Dennny").describe()
df
# Out:
#       Year        Dennny       Finland        France       Germany  \
# 0   2004.0  2.513730e+11  1.974790e+11  2.119630e+12  2.814350e+12
# 1   2005.0  2.644670e+11  2.048850e+11  2.196950e+12  2.846860e+12
# 2   2006.0  2.828850e+11  2.170890e+11  2.320540e+12  2.994700e+12
# 3   2007.0  3.194230e+11  2.563780e+11  2.660590e+12  3.425580e+12
# 4   2008.0  3.533610e+11  2.857160e+11  2.930300e+12  3.745260e+12
# 5   2009.0  3.212410e+11  2.534980e+11  2.700890e+12  3.411260e+12
# 6   2010.0  3.219950e+11  2.494240e+11  2.645190e+12  3.399670e+12
# 7   2011.0  3.440030e+11  2.756040e+11  2.865160e+12  3.749310e+12
# 8   2012.0  3.271490e+11  2.582900e+11  2.683670e+12  3.527140e+12
# 9   2013.0  3.435840e+11  2.713620e+11  2.811880e+12  3.733800e+12
# 10  2014.0  3.529940e+11  2.748630e+11  2.855960e+12  3.889090e+12
# 11  2015.0  3.026730e+11  2.345340e+11  2.439190e+12  3.357590e+12
# 12  2016.0  3.131160e+11  2.407710e+11  2.472960e+12  3.469850e+12
# ...

# %%
df.groupby("Dennny")["Year"].sum()
# Out:
# Dennny
# 1.000000e+03    2000.0
# 2.513730e+11    2004.0
# 2.644670e+11    2005.0
# 2.828850e+11    2006.0
# 3.026730e+11    2015.0
# 3.131160e+11    2016.0
# 3.194230e+11    2007.0
# 3.212410e+11    2009.0
# 3.219950e+11    2010.0
# 3.271490e+11    2012.0
# 3.321210e+11    2017.0
# 3.435840e+11    2013.0
# 3.440030e+11    2011.0
# 3.464990e+11    2019.0
# 3.529940e+11    2014.0
# 3.533610e+11    2008.0
# 3.547630e+11    2020.0
# 3.568410e+11    2018.0
# 4.001670e+11    2022.0
# 4.056880e+11    2021.0
# Name: Year, dtype: float64

# %%
df.sort_values(by='Year', ascending=False)
# Out:
#       Year        Dennny       Finland        France       Germany  \
# 18  2022.0  4.001670e+11  2.818870e+11  2.779090e+12  4.082470e+12
# 17  2021.0  4.056880e+11  2.964700e+11  2.959360e+12  4.278500e+12
# 16  2020.0  3.547630e+11  2.718860e+11  2.647420e+12  3.887730e+12
# 15  2019.0  3.464990e+11  2.685150e+11  2.728870e+12  3.889180e+12
# 14  2018.0  3.568410e+11  2.757080e+11  2.790960e+12  3.974440e+12
# 13  2017.0  3.321210e+11  2.556480e+11  2.595150e+12  3.690850e+12
# 12  2016.0  3.131160e+11  2.407710e+11  2.472960e+12  3.469850e+12
# 11  2015.0  3.026730e+11  2.345340e+11  2.439190e+12  3.357590e+12
# 10  2014.0  3.529940e+11  2.748630e+11  2.855960e+12  3.889090e+12
# 9   2013.0  3.435840e+11  2.713620e+11  2.811880e+12  3.733800e+12
# 8   2012.0  3.271490e+11  2.582900e+11  2.683670e+12  3.527140e+12
# 7   2011.0  3.440030e+11  2.756040e+11  2.865160e+12  3.749310e+12
# 6   2010.0  3.219950e+11  2.494240e+11  2.645190e+12  3.399670e+12
# ...

# %%
df.filter(like='Dennny', axis=1)
# Out:
#           Dennny
# 0   2.513730e+11
# 1   2.644670e+11
# 2   2.828850e+11
# 3   3.194230e+11
# 4   3.533610e+11
# 5   3.212410e+11
# 6   3.219950e+11
# 7   3.440030e+11
# 8   3.271490e+11
# 9   3.435840e+11
# 10  3.529940e+11
# 11  3.026730e+11
# 12  3.131160e+11
# 13  3.321210e+11
# 14  3.568410e+11
# 15  3.464990e+11
# 16  3.547630e+11
# 17  4.056880e+11
# 18  4.001670e+11
# 19  1.000000e+03

# %%
df["Dennny"].value_counts().plot(kind="line")
# Out:
# <Axes: xlabel='Dennny'>

# %%
df["means"].value_counts().plot(kind="kde")
# Out:
# <Axes: ylabel='Density'>

# %%
df["Ireland"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Ireland'>

# %%
df["Dennny"].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
df["Dennny"].value_counts().plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df["Dennny"].value_counts().plot(kind="barh")
# Out:
# <Axes: ylabel='Dennny'>

# %%
df["Dennny"].value_counts().plot(kind="box")
# Out:
# <Axes: >

# %%
df["means"].value_counts().plot(kind="density")
# Out:
# <Axes: ylabel='Density'>

# %%
df["Dennny"].value_counts().plot(kind="area")
# Out:
# <Axes: xlabel='Dennny'>
